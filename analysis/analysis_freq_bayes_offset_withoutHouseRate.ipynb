# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pymc as pm
import arviz as az
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.linear_model import LassoCV, Lasso
from sklearn.model_selection import KFold, cross_val_score



gdf = gpd.read_file(r"../data/updated_data.geojson")

#fem_house_rate has been deleted because it is obvious that if fem_house_rate is high, ratio_fem_mal will be low
col_to_del_linear_model=['geo_point_2d','urban_type','private_coverage','empl_gap']

gdf.drop(columns=col_to_del_linear_model,inplace=True)

#there is one missing value on ecec_diffusion variable
gdf["ecec_diffusion"] = gdf["ecec_diffusion"].fillna(gdf["ecec_diffusion"].median())

# %%
X=gdf.select_dtypes(include='number').drop(columns=['fem_empl_rate','mal_empl_rate'])
y=gdf['fem_empl_rate']
offset=gdf['mal_empl_rate']

# %% [markdown]
# # Correlation Part

# %%
import numpy as np

#THRESHOLD=0.9
col_to_drop=['empl_rate', 'inact_rate', 'other_per_capita_expenditure', 'adj_net_migration_rate','part_rate','unempl_rate','male_edu_rate','fem_house_rate']

X.drop(columns=col_to_drop,inplace=True)

corr_matrix=X.corr()

upper_matrix = corr_matrix.where(
    np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)
)

stacked=upper_matrix.stack()
best_pair = stacked.abs().idxmax()
best_corr_value = stacked.loc[best_pair]

print('best_pair',best_pair,'best_corr_value',best_corr_value)
# Out:
# best_pair ('fertility_rate', 'ageing_index') best_corr_value -0.8725350233934767

# %%
selected_covariates=X.columns

X = X.to_numpy()
y = y.to_numpy()/100
offset=offset.to_numpy()/100


# standardize predictors and the target
X_scaler = StandardScaler()
X_scaled = X_scaler.fit_transform(X)



y_logit = np.log(y/(1-y)) 
logit_offset=np.log(offset/(1-offset))

y_with_offset = y_logit - logit_offset


n_obs, n_feat = X_scaled.shape
print(f"\nNumber of observations: {n_obs}, number of predictors: {n_feat}")
# Out:
# Number of observations: 107, number of predictors: 37

# %% [markdown]
# # Frequentist Lasso (Credits : Chi)

# %%
cv = KFold(n_splits=10, shuffle=True, random_state=42)
lasso_cv = LassoCV(cv=cv, random_state=42, max_iter=10000)
lasso_cv.fit(X_scaled, y_with_offset)

print(f"Best alpha found: {lasso_cv.alpha_:.4f}")

lasso_final = Lasso(alpha=lasso_cv.alpha_)
lasso_final.fit(X_scaled, y_with_offset)

coef = pd.Series(lasso_final.coef_, index=selected_covariates)
nonzero_coef = coef[coef != 0].sort_values(ascending=False)
# print("\nNon-zero coefficients (variables selected by Lasso):")
# print(nonzero_coef)

r2_scores = cross_val_score(lasso_final, X_scaled, y_with_offset, cv=cv, scoring='r2')
mse_scores = -cross_val_score(lasso_final, X_scaled, y_with_offset, cv=cv, scoring='neg_mean_squared_error')
print(f"\nMean CV R²: {np.mean(r2_scores):.3f} ± {np.std(r2_scores):.3f}")
print(f"Mean CV MSE: {np.mean(mse_scores):.3f} ± {np.std(mse_scores):.3f}")

plt.figure(figsize=(8,6))
nonzero_coef.sort_values().plot(kind='barh')
# plt.title('Lasso-selected variables influencing ratio female/male employment rate')
plt.xlabel('Coefficients')
plt.grid(True)
plt.show()
# Out:
# Best alpha found: 0.0202
#
# Mean CV R²: 0.411 ± 0.299
# Mean CV MSE: 0.027 ± 0.017

# %%
y_pred = lasso_final.predict(X_scaled)

Error=y_pred-y_with_offset


plt.figure(figsize=(10,6))
plt.bar(gdf["prov_name"],Error)
plt.xlabel("prov_name")
plt.ylabel("Error")
plt.title("Error between prediction and real value")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_35745/2468796985.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Bayes Lasso (Credits : Leo)

# %%
with pm.Model() as bl_model:
    X_data = pm.Data("X_data", X_scaled)
    y_data = pm.Data("y_data", y_logit)

    lambda_ = pm.Gamma("lambda", alpha=0.1, beta=0.1)
    sigma = pm.HalfNormal("sigma", sigma=1.0)


    beta = pm.Laplace(
        "beta",
        mu=0.0,
        b=sigma / lambda_,
        shape=n_feat
    )

    # intercept = pm.Laplace("alpha", mu=0.0, b=sigma / lambda_)
    intercept = pm.Normal("alpha", mu=0.0, sigma=5.0)

    offset_values = pm.Data("offset", logit_offset)


    mu = pm.math.dot(X_data, beta) + intercept+ offset_values


    y_obs = pm.Normal("y_obs", mu=mu, sigma=sigma, observed=y_data)


    trace = pm.sample(
        draws=2000,
        tune=2000,
        target_accept=0.9,
        return_inferencedata=True,
        random_seed=42
    )
# Out:
# Initializing NUTS using jitter+adapt_diag...
# /home/atuan/miniconda3/envs/stan/lib/python3.11/site-packages/pytensor/link/c/cmodule.py:3004: UserWarning: PyTensor could not link to a BLAS installation. Operations that might benefit from BLAS will be severely degraded.
# This usually happens when PyTensor is installed via pip. We recommend it be installed via conda/mamba/pixi instead.
# Alternatively, you can use an experimental backend such as Numba or JAX that perform their own BLAS optimizations, by setting `pytensor.config.mode == 'NUMBA'` or passing `mode='NUMBA'` when compiling a PyTensor function.
# For more options and details see https://pytensor.readthedocs.io/en/latest/troubleshooting.html#how-do-i-configure-test-my-blas-library
#   warnings.warn(
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [lambda, sigma, beta, alpha]
# /home/atuan/miniconda3/envs/stan/lib/python3.11/site-packages/rich/live.py:256: UserWarning: install "ipywidgets"
# for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# /home/atuan/miniconda3/envs/stan/lib/python3.11/site-packages/pymc/step_methods/hmc/quadpotential.py:316: RuntimeWarning: overflow encountered in dot
#   return 0.5 * np.dot(x, v_out)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 36 seconds.

# %%
summary_beta = az.summary(trace, var_names=["beta"], hdi_prob=0.95)

summary_beta.index = selected_covariates

summary_beta["contains_zero"] = (
    (summary_beta["hdi_2.5%"] <= 0) &
    (summary_beta["hdi_97.5%"] >= 0)
)

# summary_beta["contains_zero"] = (
#     (summary_beta["hdi_5%"] <= 0) &
#     (summary_beta["hdi_95%"] >= 0)
# )

summary_beta = summary_beta.sort_values("mean", key=np.abs, ascending=False)

print(summary_beta[["mean", "hdi_2.5%", "hdi_97.5%", "contains_zero"]])
# print(summary_beta[["mean", "hdi_5%", "hdi_95%", "contains_zero"]])
# Out:
#                                      mean  hdi_2.5%  hdi_97.5%  contains_zero
# coverage                            0.045    -0.000      0.088           True
# young_neet                         -0.025    -0.069      0.011           True
# per_capita_user_contribution        0.023    -0.012      0.069           True
# graduate_mobility_rate              0.021    -0.015      0.072           True
# n_members_family                   -0.020    -0.061      0.012           True
# ecec_diffusion                     -0.017    -0.051      0.011           True
# per_capita_public_expenditure       0.017    -0.017      0.058           True
# avg_children_per_woman             -0.012    -0.048      0.017           True
# ecec_participation                  0.011    -0.022      0.052           True
# n_self_empl                        -0.009    -0.037      0.016           True
# eco_urban_index                     0.009    -0.015      0.039           True
# GDP                                 0.008    -0.026      0.048           True
# green_m2_capita                     0.007    -0.015      0.032           True
# net_migration_rate                  0.007    -0.026      0.043           True
# foreign_rate                        0.007    -0.021      0.040           True
# first_birth_maternal_age            0.006    -0.021      0.036           True
# empl_growth                         0.006    -0.016      0.031           True
# fem_maj_empl_rate                   0.006    -0.018      0.034           True
# dependency_rate                     0.005    -0.022      0.039           True
# public_coverage                     0.005    -0.024      0.036           True
# other_percapita_user_contrib        0.005    -0.019      0.030           True
# GERD_total_intramural               0.005    -0.021      0.035           True
# lifelong_learn                      0.004    -0.022      0.033           True
# service_empl_rate                   0.004    -0.019      0.034           True
# internet_coverage_rate             -0.004    -0.030      0.020           True
# house_price                         0.004    -0.024      0.032           True
# fem_edu_rate                        0.003    -0.025      0.031           True
# startup_ratio                       0.003    -0.022      0.029           True
# fertility_rate                     -0.003    -0.035      0.032           True
# population                         -0.002    -0.031      0.023           True
# ageing_index                        0.002    -0.031      0.035           True
# other_percapita_public_expenditure  0.002    -0.024      0.027           True
# public_transport_supply            -0.002    -0.031      0.026           True
# area_km2                           -0.001    -0.023      0.022           True
# elderly_in_care                     0.001    -0.022      0.024           True
# n_large_comp                       -0.001    -0.032      0.028           True
# advanced_business_empl              0.000    -0.031      0.035           True

# %%
beta_samples = trace.posterior["beta"].stack(samples=("chain", "draw")).values

plt.figure(figsize=(12,4))

for i in range(beta_samples.shape[0]):
    # if (selected_covariates[i] in ['empl_rate','coverage','ratio_edu_rate','n_members_family','graduate_mobility_rate']):
    #     sns.kdeplot(beta_samples[i, :],label=selected_covariates[i])
    # else:
        sns.kdeplot(beta_samples[i, :])

plt.legend()
plt.title("Posterior density of β_{j}")
plt.xlabel("Values of β_{j}")
plt.yticks([])     
plt.gca().tick_params(axis='y', length=0)

plt.show()
# Out:
# /tmp/ipykernel_35745/1014072038.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
important_covariates=summary_beta[summary_beta["mean"].abs()>0.027]['mean']

plt.figure(figsize=(8,6))
important_covariates.sort_values().plot(kind='barh')
plt.grid(True)
plt.show()

# %% [markdown]
# # Spike and Slab

# %%
with pm.Model() as ss_model:
    # Data
    X_data = pm.Data("X_data", X_scaled)
    y_data = pm.Data("y_data", y_logit)
    offset_vals = pm.Data("offset", logit_offset)

    # Likelihood noise on logit scale
    sigma = pm.HalfNormal("sigma", sigma=1.0)

    # ---- Spike-and-Slab Prior ----
    # Inclusion probability (can be hierarchical if you want)
    # pi = pm.Beta("pi", alpha=1, beta=1)   # uniform prior for inclusion
    pi = 0.5 # fixed inclusion probability - uniform prior over all the models

    # Spike: indicator for inclusion/exclusion
    gamma = pm.Bernoulli("gamma", p=pi, shape=n_feat)

    # Slab: wide Normal prior for coefficients
    beta_slab = pm.Normal("beta_slab", mu=0.0, sigma=5.0, shape=n_feat)

    # Actual beta = spike * slab
    beta = pm.Deterministic("beta", gamma * beta_slab)

    # Intercept: do NOT shrink it
    intercept = pm.Normal("alpha", mu=0.0, sigma=5.0)

    # Linear predictor
    mu = pm.math.dot(X_data, beta) + intercept + offset_vals

    # Likelihood: Gaussian on logit-transformed employment rate
    y_obs = pm.Normal("y_obs", mu=mu, sigma=sigma, observed=y_data)

    # Sampling
    trace = pm.sample(
        draws=2000,
        tune=2000,
        target_accept=0.9,
        return_inferencedata=True,
        random_seed=42
    )
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [sigma, beta_slab, alpha]
# >BinaryGibbsMetropolis: [gamma]
# /home/atuan/miniconda3/envs/stan/lib/python3.11/site-packages/rich/live.py:256: UserWarning: install "ipywidgets"
# for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 314 seconds.
# There were 1319 divergences after tuning. Increase `target_accept` or reparameterize.
# Chain 0 reached the maximum tree depth. Increase `max_treedepth`, increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details

# %%
summary_beta = az.summary(trace, var_names=["beta"], hdi_prob=0.95)

summary_beta.index = selected_covariates

summary_beta["contains_zero"] = (
    (summary_beta["hdi_2.5%"] <= 0) &
    (summary_beta["hdi_97.5%"] >= 0)
)

# summary_beta["contains_zero"] = (
#     (summary_beta["hdi_5%"] <= 0) &
#     (summary_beta["hdi_95%"] >= 0)
# )

summary_beta = summary_beta.sort_values("mean", key=np.abs, ascending=False)

print(summary_beta[["mean", "hdi_2.5%", "hdi_97.5%", "contains_zero"]])
# print(summary_beta[["mean", "hdi_5%", "hdi_95%", "contains_zero"]])
# Out:
#                                      mean  hdi_2.5%  hdi_97.5%  contains_zero
# coverage                            0.101     0.053      0.152          False
# graduate_mobility_rate              0.050    -0.000      0.107           True
# n_members_family                   -0.043    -0.092     -0.000           True
# per_capita_user_contribution        0.006     0.000      0.072           True
# per_capita_public_expenditure       0.005    -0.000      0.048           True
# young_neet                         -0.005    -0.057      0.000           True
# ecec_participation                  0.003    -0.000      0.000           True
# GERD_total_intramural               0.002    -0.000     -0.000           True
# avg_children_per_woman             -0.001     0.000      0.000           True
# ecec_diffusion                     -0.001    -0.000      0.000           True
# population                         -0.000    -0.000     -0.000           True
# fem_edu_rate                        0.000    -0.000     -0.000           True
# empl_growth                         0.000    -0.000      0.000           True
# GDP                                 0.000    -0.000     -0.000           True
# service_empl_rate                   0.000     0.000      0.000           True
# fertility_rate                     -0.000    -0.000     -0.000           True
# n_self_empl                        -0.000     0.000      0.000           True
# foreign_rate                        0.000    -0.000     -0.000           True
# elderly_in_care                    -0.000    -0.000     -0.000           True
# house_price                        -0.000     0.000      0.000           True
# n_large_comp                       -0.000     0.000     -0.000           True
# internet_coverage_rate             -0.000     0.000     -0.000           True
# public_transport_supply            -0.000    -0.000     -0.000           True
# area_km2                           -0.000     0.000     -0.000           True
# net_migration_rate                  0.000    -0.000     -0.000           True
# ageing_index                        0.000    -0.000      0.000           True
# dependency_rate                     0.000    -0.000      0.000           True
# first_birth_maternal_age            0.000     0.000      0.000           True
# green_m2_capita                     0.000    -0.000     -0.000           True
# advanced_business_empl              0.000    -0.000     -0.000           True
# eco_urban_index                     0.000    -0.000      0.000           True
# startup_ratio                       0.000    -0.000      0.000           True
# lifelong_learn                      0.000     0.000      0.000           True
# public_coverage                     0.000     0.000     -0.000           True
# other_percapita_public_expenditure  0.000    -0.000      0.000           True
# other_percapita_user_contrib        0.000    -0.000      0.000           True
# fem_maj_empl_rate                  -0.000    -0.000     -0.000           True

# %%
beta_samples = trace.posterior["beta"].stack(samples=("chain", "draw")).values

plt.figure(figsize=(12,4))

for i in range(beta_samples.shape[0]):
    # if (selected_covariates[i] in ['empl_rate','coverage','ratio_edu_rate','n_members_family','graduate_mobility_rate']):
    #     sns.kdeplot(beta_samples[i, :],label=selected_covariates[i])
    # else:
        sns.kdeplot(beta_samples[i, :])

plt.legend()
plt.title("Posterior density of β_{j}")
plt.xlabel("Values of β_{j}")
plt.yticks([])     
plt.gca().tick_params(axis='y', length=0)

plt.show()
# Out:
# /tmp/ipykernel_35745/1014072038.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
important_covariates=summary_beta[summary_beta["mean"].abs()>0.027]['mean']

plt.figure(figsize=(8,6))
important_covariates.sort_values().plot(kind='barh')
plt.grid(True)
plt.show()

# %% [markdown]
# # Horseshoe

# %%
with pm.Model() as hs_model:
    # Data
    X_data = pm.Data("X_data", X_scaled)
    y_data = pm.Data("y_data", y_logit)
    offset_vals = pm.Data("offset", logit_offset)

    # Likelihood noise on logit scale
    sigma = pm.HalfNormal("sigma", sigma=1.0)

    # ---- Horseshoe Prior for beta ----
    tau = pm.HalfCauchy("tau", beta=1.0)  # global shrinkage
    lam = pm.HalfCauchy("lam", beta=1.0, shape=n_feat)  # local shrinkage
    # actual beta
    beta = pm.Normal("beta", mu=0.0, sigma=tau*lam, shape=n_feat)

    # Intercept
    intercept = pm.Normal("alpha", mu=0.0, sigma=5.0)

    # Linear predictor
    mu = pm.math.dot(X_data, beta) + intercept + offset_vals

    # Likelihood: Gaussian on logit-transformed outcome
    y_obs = pm.Normal("y_obs", mu=mu, sigma=sigma, observed=y_data)

    # Sampling
    trace = pm.sample(
        draws=2000,
        tune=2000,
        target_accept=0.9,
        return_inferencedata=True,
        random_seed=42
    )
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, tau, lam, beta, alpha]
# /home/atuan/miniconda3/envs/stan/lib/python3.11/site-packages/rich/live.py:256: UserWarning: install "ipywidgets"
# for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 218 seconds.
# There were 3248 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details

# %%
summary_beta = az.summary(trace, var_names=["beta"], hdi_prob=0.95)

summary_beta.index = selected_covariates

summary_beta["contains_zero"] = (
    (summary_beta["hdi_2.5%"] <= 0) &
    (summary_beta["hdi_97.5%"] >= 0)
)

# summary_beta["contains_zero"] = (
#     (summary_beta["hdi_5%"] <= 0) &
#     (summary_beta["hdi_95%"] >= 0)
# )

summary_beta = summary_beta.sort_values("mean", key=np.abs, ascending=False)

print(summary_beta[["mean", "hdi_2.5%", "hdi_97.5%", "contains_zero"]])
# print(summary_beta[["mean", "hdi_5%", "hdi_95%", "contains_zero"]])
# Out:
#                                      mean  hdi_2.5%  hdi_97.5%  contains_zero
# coverage                            0.068    -0.002      0.118           True
# young_neet                         -0.029    -0.079      0.010           True
# per_capita_public_expenditure       0.024    -0.011      0.066           True
# graduate_mobility_rate              0.020    -0.010      0.095           True
# per_capita_user_contribution        0.019    -0.010      0.088           True
# n_members_family                   -0.016    -0.069      0.010           True
# ecec_diffusion                     -0.010    -0.054      0.014           True
# ecec_participation                  0.006    -0.019      0.049           True
# avg_children_per_woman             -0.006    -0.035      0.010           True
# public_coverage                     0.006    -0.015      0.026           True
# GDP                                 0.004    -0.026      0.031           True
# GERD_total_intramural               0.004    -0.013      0.031           True
# n_self_empl                        -0.004    -0.026      0.013           True
# net_migration_rate                  0.003    -0.017      0.033           True
# dependency_rate                     0.003    -0.018      0.027           True
# first_birth_maternal_age            0.003    -0.008      0.036           True
# eco_urban_index                     0.003    -0.012      0.023           True
# foreign_rate                        0.002    -0.014      0.027           True
# service_empl_rate                   0.002    -0.012      0.024           True
# empl_growth                         0.002    -0.010      0.020           True
# fem_edu_rate                        0.002    -0.014      0.020           True
# fertility_rate                     -0.002    -0.028      0.017           True
# green_m2_capita                     0.002    -0.012      0.021           True
# other_percapita_user_contrib        0.002    -0.012      0.021           True
# lifelong_learn                      0.002    -0.015      0.023           True
# ageing_index                        0.002    -0.019      0.029           True
# other_percapita_public_expenditure  0.001    -0.014      0.017           True
# house_price                         0.001    -0.016      0.021           True
# n_large_comp                       -0.001    -0.023      0.014           True
# fem_maj_empl_rate                   0.001    -0.013      0.023           True
# startup_ratio                       0.001    -0.016      0.017           True
# area_km2                           -0.001    -0.015      0.015           True
# internet_coverage_rate             -0.001    -0.020      0.013           True
# population                          0.000    -0.016      0.018           True
# elderly_in_care                     0.000    -0.016      0.015           True
# public_transport_supply            -0.000    -0.018      0.016           True
# advanced_business_empl              0.000    -0.018      0.020           True

# %%
beta_samples = trace.posterior["beta"].stack(samples=("chain", "draw")).values

plt.figure(figsize=(12,4))

for i in range(beta_samples.shape[0]):
    # if (selected_covariates[i] in ['empl_rate','coverage','ratio_edu_rate','n_members_family','graduate_mobility_rate']):
    #     sns.kdeplot(beta_samples[i, :],label=selected_covariates[i])
    # else:
        sns.kdeplot(beta_samples[i, :])

plt.legend()
plt.title("Posterior density of β_{j}")
plt.xlabel("Values of β_{j}")
plt.yticks([])     
plt.gca().tick_params(axis='y', length=0)

plt.show()
# Out:
# /tmp/ipykernel_35745/1014072038.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
important_covariates=summary_beta[summary_beta["mean"].abs()>0.027]['mean']

plt.figure(figsize=(8,6))
important_covariates.sort_values().plot(kind='barh')
plt.grid(True)
plt.show()
